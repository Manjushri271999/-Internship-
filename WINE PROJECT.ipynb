# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
ws=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Red%20Wine/winequality-red.csv')
ws
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
ws.head( )
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
ws.describe( )
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
ws.isnull( ).sum( )
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
sns.catplot(x='quality',data= ws, kind='count')

# %% [markdown]
# ws.info( )

# %%
plot =plt.figure(figsize=(5,5))
sns.barplot(x='quality', y='volatile acidity', data= ws)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
plot =plt.figure(figsize=(5,5))
sns.barplot(x='quality', y='citric acid', data= ws)
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
correlation = ws.corr( )

# %%
plt.figure(figsize=(10,10))
sns.heatmap(correlation, cbar= True, square=True, fmt= '.1f', annot = True, annot_kws= {'size':8}, cmap='Blues')
# Out:
# <Axes: >

# %%
sns.heatmap(ws.isnull( ))
# Out:
# <Axes: >

# %%
ws['quality'].unique( )
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
ws['quality'].nunique( )
# Out:
# 6

# %%
ws.groupby('quality').mean( )
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
ws.plot(kind='box',subplots=True,layout=(4,4),sharex=False)
# Out:
# fixed acidity              Axes(0.125,0.712609;0.168478x0.167391)
# volatile acidity        Axes(0.327174,0.712609;0.168478x0.167391)
# citric acid             Axes(0.529348,0.712609;0.168478x0.167391)
# residual sugar          Axes(0.731522,0.712609;0.168478x0.167391)
# chlorides                  Axes(0.125,0.511739;0.168478x0.167391)
# free sulfur dioxide     Axes(0.327174,0.511739;0.168478x0.167391)
# total sulfur dioxide    Axes(0.529348,0.511739;0.168478x0.167391)
# density                 Axes(0.731522,0.511739;0.168478x0.167391)
# pH                          Axes(0.125,0.31087;0.168478x0.167391)
# sulphates                Axes(0.327174,0.31087;0.168478x0.167391)
# alcohol                  Axes(0.529348,0.31087;0.168478x0.167391)
# quality                  Axes(0.731522,0.31087;0.168478x0.167391)
# dtype: object

# %%
ws['fixed acidity'].plot(kind='box')
# Out:
# <Axes: >

# %%
ws.hist(figsize=(10,10),bins=50)
plt.show( )

# %%
ws.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 826             7.5             0.270         0.34             2.3      0.050
# 510            12.4             0.420         0.49             4.6      0.073
# 917             6.8             0.410         0.31             8.8      0.084
# 1351            7.2             0.620         0.01             2.3      0.065
# 525            10.4             0.640         0.24             2.8      0.105
# 1568            7.0             0.560         0.13             1.6      0.077
# 1430            7.4             0.410         0.24             1.8      0.066
# 299             6.9             0.670         0.06             2.1      0.080
# 1255            6.1             0.640         0.02             2.4      0.069
# 776             6.9             0.765         0.18             2.4      0.243
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
ws['goodquality']=[1 if x >= 7 else 0 for x in ws['quality']]
ws.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 13              7.8             0.610         0.29             1.6      0.114
# 596            12.4             0.400         0.51             2.0      0.059
# 270             7.9             0.545         0.06             4.0      0.087
# 1542            6.7             0.855         0.02             1.9      0.064
# 1458            8.4             0.290         0.40             1.7      0.067
# 1219            9.0             0.390         0.40             1.3      0.044
# 186             7.4             0.390         0.48             2.0      0.082
# 1506            6.8             0.810         0.05             2.0      0.070
# 96              6.8             0.775         0.00             3.0      0.102
# 1557            6.6             0.855         0.02             2.4      0.062
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
A=ws.drop( ['quality' , 'goodquality' ], axis = 1)
B=ws['goodquality']

# %%
ws['goodquality'].value_counts( )
# Out:
# 0    1382
# 1     217
# Name: goodquality, dtype: int64

# %%
A
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
print(B)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: goodquality, Length: 1599, dtype: int64
