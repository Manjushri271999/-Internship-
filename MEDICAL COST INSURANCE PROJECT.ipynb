# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
icost=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Medical%20Cost%20Insurance/medical_cost_insurance.csv')
icost
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
icost.head( )
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
icost.tail( )
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
icost.describe( )
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
icost.isnull( ).sum( )
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
icost.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
icost.info( )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='sex', data=icost)
plt.title('Gender Distribution')
plt.show( )

# %%
sns.countplot(x='smoker', data=icost)
plt.title('smoker')
plt.show( )

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='region',data=icost)
plt.title('Region')
plt.show( )

# %%
plt.figure(figsize=(5,5))
sns.barplot(x='region',y='charges',data=icost)
plt.title('Cost vs Region ')
# Out:
# Text(0.5, 1.0, 'Cost vs Region ')

# %%
plt.figure(figsize=(5,5))
sns.barplot(x='smoker',y='charges',data=icost)
plt.title('Charges for Smokers')
# Out:
# Text(0.5, 1.0, 'Charges for Smokers')

# %%
plt.figure(figsize=(5,5))
sns.barplot(x='sex', y='charges',hue='smoker',data=icost)
plt.title('Charges for Smokers')
# Out:
# Text(0.5, 1.0, 'Charges for Smokers')

# %%
fig, axes= plt.subplots(1,3, figsize=(15,5), sharey= True)
fig.suptitle('Visualizing categorial columns ')
sns.boxenplot(x='smoker', y='charges',data=icost,ax=axes[0])
sns.boxenplot(x='sex', y='charges',data=icost,ax=axes[1])
sns.boxenplot(x='region', y='charges',data=icost,ax=axes[2])
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %%
icost[['age','bmi','children','charges']].hist(bins=30, figsize=(10,10), color='blue')
plt.show( )

# %%
icost.head( )
# Out:
#    age   sex     bmi  children smoker region      charges
# 0   19  None  27.900         0   None   None  16884.92400
# 1   18  None  33.770         1   None   None   1725.55230
# 2   28  None  33.000         3   None   None   4449.46200
# 3   33  None  22.705         0   None   None  21984.47061
# 4   32  None  28.880         0   None   None   3866.85520

# %%
icost['sex'] = icost['sex'].apply({'male':0, 'female':1}.get)
icost['smoker'] = icost['smoker'].apply({'yes':1, 'no':0}.get)
icost['region'] = icost['region'].apply({'southwest':1, 'southeast':2, 'northwest':3, 'northeast':4}.get)

# %%
plt.figure(figsize=(10,7))
sns.heatmap(icost.corr( ), annot = True)
plt.show( )

# %%
icost.head( )
# Out:
#    age   sex     bmi  children smoker region      charges
# 0   19  None  27.900         0   None   None  16884.92400
# 1   18  None  33.770         1   None   None   1725.55230
# 2   28  None  33.000         3   None   None   4449.46200
# 3   33  None  22.705         0   None   None  21984.47061
# 4   32  None  28.880         0   None   None   3866.85520

# %%
x= icost.drop(['charges' , 'sex'], axis=1)
y= icost.charges

# %%
data={}
